# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("2022_US_Region_Mobility_Report.csv")

# %%
king_df = df[(df["sub_region_1"] == "Washington") & (df["sub_region_2"] == "King County")].iloc[:, 8:15]
king_df
# Out:
#               date  retail_and_recreation_percent_change_from_baseline  \
# 704562  2022-01-01                                              -54.0
# 704563  2022-01-02                                              -27.0
# 704564  2022-01-03                                              -26.0
# 704565  2022-01-04                                              -28.0
# 704566  2022-01-05                                              -29.0
# ...            ...                                                ...
# 704845  2022-10-11                                              -18.0
# 704846  2022-10-12                                              -19.0
# 704847  2022-10-13                                              -21.0
# 704848  2022-10-14                                              -18.0
# 704849  2022-10-15                                              -19.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 704562                                              -41.0
# ...

# %% [markdown]
# ## Visualization 1

# %%
king_df.plot(x="date", 
             y=[
                 "retail_and_recreation_percent_change_from_baseline", 
                 "grocery_and_pharmacy_percent_change_from_baseline", 
                 "parks_percent_change_from_baseline", 
                 "transit_stations_percent_change_from_baseline",
                 "workplaces_percent_change_from_baseline",
                 "residential_percent_change_from_baseline"
             ],
             figsize = (15, 8))
plt.title("Mobility Metric by Time (2022)")
plt.xlabel("Time (2022)")
plt.ylabel("Relative Change from Baseline");

# %%
fuel_prices = pd.read_csv("Weekly_Seattle_WA_All_Grades_All_Formulations_Retail_Gasoline_Prices.csv")
fuel_prices = fuel_prices.loc[::-1].reset_index(drop=True)
fuel_prices
# Out:
#           Date  Fuel_Price
# 0    01/3/2022       4.001
# 1   01/10/2022       4.086
# 2   01/17/2022       4.106
# 3   01/24/2022       4.106
# 4   01/31/2022       4.128
# 5    02/7/2022       4.122
# 6   02/14/2022       4.119
# 7   02/21/2022       4.146
# 8   02/28/2022       4.189
# 9    03/7/2022       4.606
# 10  03/14/2022       4.898
# 11  03/21/2022       4.834
# 12  03/28/2022       4.853
# 13   04/4/2022       4.787
# 14  04/11/2022       4.747
# 15  04/18/2022       4.753
# 16  04/25/2022       4.779
# 17   05/2/2022       4.798
# 18   05/9/2022       4.898
# 19  05/16/2022       5.083
# 20  05/23/2022       5.286
# 21  05/30/2022       5.335
# 22   06/6/2022       5.512
# 23  06/13/2022       5.645
# 24  06/20/2022       5.610
# 25  06/27/2022       5.558
# 26   07/4/2022       5.507
# 27  07/11/2022       5.405
# 28  07/18/2022       5.257
# 29  07/25/2022       5.180
# 30   08/1/2022       5.100
# 31   08/8/2022       4.983
# 32  08/15/2022       4.908
# ...

# %% [markdown]
# ## Visualization 2

# %%
fuel_prices.plot(x="Date", y="Fuel_Price")
plt.title("Fuel Prices in King County (WA) in 2022")
plt.xlabel("Date")
plt.ylabel("Fuel Price (USD)");

# %% [markdown]
# ## Visualization 3

# %%
days = []
for i in range(len(king_df)):
    if i % 7 == 0:
        days.append("Saturday")
    elif i % 7 == 1:
        days.append("Sunday")
    elif i % 7 == 2:
        days.append("Monday")
    elif i % 7 == 3:
        days.append("Tuesday")
    elif i % 7 == 4:
        days.append("Wednesday")
    elif i % 7 == 5:
        days.append("Thursday")
    elif i % 7 == 6:
        days.append("Friday")
king_df["Day"] = days
king_df[31:60].plot(x="date", 
             y=[
                 "retail_and_recreation_percent_change_from_baseline", 
                 "grocery_and_pharmacy_percent_change_from_baseline", 
                 "parks_percent_change_from_baseline", 
                 "transit_stations_percent_change_from_baseline",
                 "workplaces_percent_change_from_baseline",
                 "residential_percent_change_from_baseline"
             ],
             figsize = (15, 8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
king_df[31:60]
# Out:
#               date  retail_and_recreation_percent_change_from_baseline  \
# 704593  2022-02-01                                              -24.0
# 704594  2022-02-02                                              -27.0
# 704595  2022-02-03                                              -27.0
# 704596  2022-02-04                                              -26.0
# 704597  2022-02-05                                              -25.0
# 704598  2022-02-06                                              -15.0
# 704599  2022-02-07                                              -28.0
# 704600  2022-02-08                                              -24.0
# 704601  2022-02-09                                              -24.0
# 704602  2022-02-10                                              -26.0
# 704603  2022-02-11                                              -24.0
# 704604  2022-02-12                                              -20.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z3/nzdjs9l52974wlrgl05jpcjc0000gn/T/ipykernel_3248/4053942486.py in <module>
# ----> 1 heatmap = sns.heatmap(dataframe.corr(), vmin=-1, vmax=1, annot=True)
#
# NameError: name 'sns' is not defined
