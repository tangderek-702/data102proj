# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
from scipy.stats.stats import pearsonr
import numpy as np
from sklearn.utils import resample
import sklearn.linear_model as lm

# %% [markdown]
# # DATAC102 Final Project: Fuel Prices & Mobility from 2020-2022 #

# %% [markdown]
# Alina Herri, Nick Wong, Genie Lee, Derek Tang
# Fall 2022

# %% [markdown]
# # Datasets

# %% [markdown]
# ## Google Mobility Data From King County (2020-2022)

# %%
king_county_2020 = pd.read_csv('2020_US_Region_Mobility_Report.csv')
king_county_2020 = king_county_2020[(king_county_2020.sub_region_1 == 'Washington') & (king_county_2020.sub_region_2 == 'King County')]

king_county_2021 = pd.read_csv('2021_US_Region_Mobility_Report.csv')
king_county_2021 = king_county_2021[(king_county_2021.sub_region_1 == 'Washington') & (king_county_2021.sub_region_2 == 'King County')]

king_county_2022 = pd.read_csv('2022_US_Region_Mobility_Report.csv')
king_county_2022 = king_county_2022[(king_county_2022.sub_region_1 == 'Washington') & (king_county_2022.sub_region_2 == 'King County')]

# %%
king_df = pd.concat([king_county_2020,king_county_2021,king_county_2022]).iloc[:, 8:15]

# %%
days = []
for i in range(len(king_df)):
    if i % 7 == 0:
        days.append("Saturday")
    elif i % 7 == 1:
        days.append("Sunday")
    elif i % 7 == 2:
        days.append("Monday")
    elif i % 7 == 3:
        days.append("Tuesday")
    elif i % 7 == 4:
        days.append("Wednesday")
    elif i % 7 == 5:
        days.append("Thursday")
    elif i % 7 == 6:
        days.append("Friday")
king_df["Day"] = days

# %%
king_df
# Out:
#               date  retail_and_recreation_percent_change_from_baseline  \
# 765150  2020-02-15                                               -1.0
# 765151  2020-02-16                                               13.0
# 765152  2020-02-17                                               10.0
# 765153  2020-02-18                                                4.0
# 765154  2020-02-19                                                2.0
# ...            ...                                                ...
# 704845  2022-10-11                                              -18.0
# 704846  2022-10-12                                              -19.0
# 704847  2022-10-13                                              -21.0
# 704848  2022-10-14                                              -18.0
# 704849  2022-10-15                                              -19.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 765150                                               -2.0
# 765151                                                1.0
# 765152                                                4.0
# 765153                                                2.0
# 765154                                                2.0
# ...                                                   ...
# 704845                                              -10.0
# 704846                                              -10.0
# 704847                                              -10.0
# 704848                                               -9.0
# 704849                                              -15.0
#
#         parks_percent_change_from_baseline  \
# 765150                                11.0
# 765151                                19.0
# 765152                                64.0
# 765153                                51.0
# 765154                                62.0
# ...                                    ...
# 704845                                24.0
# 704846                                23.0
# 704847                                10.0
# 704848                                16.0
# 704849                                13.0
#
#         transit_stations_percent_change_from_baseline  \
# 765150                                            8.0
# 765151                                            3.0
# 765152                                          -13.0
# 765153                                            6.0
# 765154                                            6.0
# ...                                               ...
# 704845                                          -29.0
# 704846                                          -33.0
# 704847                                          -30.0
# 704848                                          -29.0
# 704849                                            1.0
#
#         workplaces_percent_change_from_baseline  \
# 765150                                     -3.0
# 765151                                     -2.0
# 765152                                    -40.0
# 765153                                     -8.0
# 765154                                     -7.0
# ...                                         ...
# 704845                                    -40.0
# 704846                                    -41.0
# 704847                                    -41.0
# 704848                                    -44.0
# 704849                                    -16.0
#
#         residential_percent_change_from_baseline        Day
# 765150                                       0.0   Saturday
# 765151                                      -1.0     Sunday
# 765152                                       7.0     Monday
# 765153                                       1.0    Tuesday
# 765154                                       0.0  Wednesday
# ...                                          ...        ...
# 704845                                       9.0    Tuesday
# 704846                                       9.0  Wednesday
# 704847                                       9.0   Thursday
# 704848                                       9.0     Friday
# 704849                                       1.0   Saturday
#
# [974 rows x 8 columns]

# %% [markdown]
# ## US Energy Information Administration Fuel Prices for King County

# %%
fuel_prices = pd.read_csv('washington_gas_prices_2020-2022.csv')
fuel_prices = fuel_prices.loc[::-1].reset_index(drop=True)
fuel_prices
# Out:
#              Date  Price Per Gallon
# 0    Nov 21, 2022             4.822
# 1    Nov 14, 2022             4.901
# 2    Nov 07, 2022             4.879
# 3    Oct 31, 2022             4.934
# 4    Oct 24, 2022             5.049
# ..            ...               ...
# 146  Feb 03, 2020             3.108
# 147  Jan 27, 2020             3.107
# 148  Jan 20, 2020             3.142
# 149  Jan 13, 2020             3.134
# 150  Jan 06, 2020             3.181
#
# [151 rows x 2 columns]

# %%
for index,date in enumerate(fuel_prices['Date']):
    fuel_prices['Date'][index] = datetime.strptime(date,"%b %d, %Y")
    
for index,date in enumerate(fuel_prices['Date']):
    fuel_prices['Date'][index] = date.strftime("%Y-%m-%d")
    
fuel_prices = fuel_prices.rename(columns={'Date':'date'})
# Out:
# /Users/alinaherri/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/alinaherri/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
combined = king_df.merge(fuel_prices,how='left',on='date')
combined[['Price Per Gallon']] = combined[['Price Per Gallon']].fillna(method='bfill')
combined['date'] = pd.to_datetime(combined['date'])
combined.sort_values(by='date')
# Out:
#           date  retail_and_recreation_percent_change_from_baseline  \
# 0   2020-02-15                                               -1.0
# 1   2020-02-16                                               13.0
# 2   2020-02-17                                               10.0
# 3   2020-02-18                                                4.0
# 4   2020-02-19                                                2.0
# ..         ...                                                ...
# 969 2022-10-11                                              -18.0
# 970 2022-10-12                                              -19.0
# 971 2022-10-13                                              -21.0
# 972 2022-10-14                                              -18.0
# 973 2022-10-15                                              -19.0
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                 -2.0
# 1                                                  1.0
# 2                                                  4.0
# 3                                                  2.0
# 4                                                  2.0
# ..                                                 ...
# 969                                              -10.0
# 970                                              -10.0
# 971                                              -10.0
# 972                                               -9.0
# 973                                              -15.0
#
#      parks_percent_change_from_baseline  \
# 0                                  11.0
# 1                                  19.0
# 2                                  64.0
# 3                                  51.0
# 4                                  62.0
# ..                                  ...
# 969                                24.0
# 970                                23.0
# 971                                10.0
# 972                                16.0
# 973                                13.0
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              8.0
# 1                                              3.0
# 2                                            -13.0
# 3                                              6.0
# 4                                              6.0
# ..                                             ...
# 969                                          -29.0
# 970                                          -33.0
# 971                                          -30.0
# 972                                          -29.0
# 973                                            1.0
#
#      workplaces_percent_change_from_baseline  \
# 0                                       -3.0
# 1                                       -2.0
# 2                                      -40.0
# 3                                       -8.0
# 4                                       -7.0
# ..                                       ...
# 969                                    -40.0
# 970                                    -41.0
# 971                                    -41.0
# 972                                    -44.0
# 973                                    -16.0
#
#      residential_percent_change_from_baseline        Day  Price Per Gallon
# 0                                         0.0   Saturday             3.125
# 1                                        -1.0     Sunday             3.125
# 2                                         7.0     Monday             3.125
# 3                                         1.0    Tuesday             3.116
# 4                                         0.0  Wednesday             3.116
# ..                                        ...        ...               ...
# 969                                       9.0    Tuesday               NaN
# 970                                       9.0  Wednesday               NaN
# 971                                       9.0   Thursday               NaN
# 972                                       9.0     Friday               NaN
# 973                                       1.0   Saturday               NaN
#
# [974 rows x 9 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ##  VIZ 1: Mobility WoW Line Graph

# %%
king_df.plot(x="date", 
             y=[
                 "retail_and_recreation_percent_change_from_baseline", 
                 "grocery_and_pharmacy_percent_change_from_baseline", 
                 "parks_percent_change_from_baseline", 
                 "transit_stations_percent_change_from_baseline",
                 "workplaces_percent_change_from_baseline",
                 "residential_percent_change_from_baseline"
             ],
             figsize = (20, 8))
plt.title("Mobility Metric by Time")
plt.xlabel("Time")
plt.ylabel("Relative Change from Baseline");

# %%
king_df[717:745].plot(x="date", 
             y=[
                 "retail_and_recreation_percent_change_from_baseline", 
                 "grocery_and_pharmacy_percent_change_from_baseline", 
                 "parks_percent_change_from_baseline", 
                 "transit_stations_percent_change_from_baseline",
                 "workplaces_percent_change_from_baseline",
                 "residential_percent_change_from_baseline"
             ],
             figsize = (15, 8));
plt.title("Mobility WoW Line Graph");

# %% [markdown]
# ## VIZ 2: Fuel Price Line Graph

# %%
fuel_prices.plot(x="date", y='Price Per Gallon',figsize = (10,10))
plt.title("Fuel Price Line Graph")
plt.xlim(fuel_prices.index[-1],fuel_prices.index[0])
plt.xlabel("Date")
plt.ylabel("Fuel Price (USD)");

# %% [markdown]
# ## VIZ 3: Fuel Price per Gallon v. Mobility Heatmap

# %%
sns.set(rc={"figure.figsize":(10, 10)})
dataplot = sns.heatmap(combined.corr(),annot=True).set_title('Fuel Price per Gallon v. Mobility Heatmap')

# %% [markdown]
# ## VIZ 4: Mobility Metric Distributions by Day of the Week

# %%
sns.set(rc={"figure.figsize":(10, 10)})
sns.boxplot(x ='Day', y ='residential_percent_change_from_baseline', data = king_df).set_title('Residential Mobility by Day of the Week');

# %%
sns.set(rc={"figure.figsize":(10, 10)})
sns.boxplot(x ='Day', y ='workplaces_percent_change_from_baseline', data = king_df).set_title('Workplace Mobility by Day of the Week');

# %% [markdown]
# ## VIZ 5: Mobility Metric Distributions (Residential) by Month

# %%
months = []
for index,date in enumerate(king_df['date']):
    months.append(calendar.month_name[datetime.strptime(date,"%Y-%m-%d").month])
king_df["Month"] = months

# %%
sns.boxplot(x ='Month', y ='residential_percent_change_from_baseline', data = king_df).set_title('Mobility Metric Distributions (Residential) by Month')
plt.xticks(rotation=45);

# %% [markdown]
# # Multiple Hypothesis Testing

# %%
king_df["datetime"] = pd.to_datetime(king_df["date"])

# %%
king_df_weekly = king_df.groupby([pd.Grouper(key="datetime", freq="W-MON")]).mean().reset_index()
king_df_weekly
# Out:
#       datetime  retail_and_recreation_percent_change_from_baseline  \
# 0   2020-02-17                                           7.333333
# 1   2020-02-24                                           2.428571
# 2   2020-03-02                                           4.285714
# 3   2020-03-09                                          -6.142857
# 4   2020-03-16                                         -17.285714
# ..         ...                                                ...
# 135 2022-09-19                                         -16.142857
# 136 2022-09-26                                         -16.285714
# 137 2022-10-03                                         -14.857143
# 138 2022-10-10                                         -18.142857
# 139 2022-10-17                                         -19.000000
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                             1.000000
# 1                                            -1.142857
# 2                                             3.714286
# 3                                             1.142857
# 4                                             4.714286
# ..                                                 ...
# 135                                          -9.285714
# 136                                          -9.285714
# 137                                          -9.428571
# 138                                         -10.428571
# 139                                         -10.800000
#
#      parks_percent_change_from_baseline  \
# 0                             31.333333
# 1                             38.142857
# 2                             30.857143
# 3                             24.142857
# 4                             22.142857
# ..                                  ...
# 135                           28.000000
# 136                           29.714286
# 137                           26.285714
# 138                           18.714286
# 139                           17.200000
#
#      transit_stations_percent_change_from_baseline  \
# 0                                        -0.666667
# 1                                         3.857143
# 2                                         3.285714
# 3                                       -15.000000
# 4                                       -33.000000
# ..                                             ...
# 135                                     -18.857143
# 136                                     -19.428571
# 137                                     -20.000000
# 138                                     -23.285714
# 139                                     -24.000000
#
#      workplaces_percent_change_from_baseline  \
# 0                                 -15.000000
# 1                                  -3.428571
# 2                                   1.000000
# 3                                 -12.428571
# 4                                 -28.000000
# ..                                       ...
# 135                               -35.285714
# 136                               -35.142857
# 137                               -34.000000
# 138                               -33.714286
# 139                               -36.400000
#
#      residential_percent_change_from_baseline
# 0                                    2.000000
# 1                                    0.000000
# 2                                   -0.285714
# 3                                    5.428571
# 4                                   10.857143
# ..                                        ...
# 135                                  6.142857
# 136                                  6.285714
# 137                                  6.285714
# 138                                  6.714286
# 139                                  7.400000
#
# [140 rows x 7 columns]

# %%
fuel_prices_weekly = fuel_prices.loc[::-1].reset_index(drop=True).iloc[6:,:]
fuel_prices_weekly["datetime"] = pd.to_datetime(fuel_prices_weekly["date"])
fuel_prices_weekly
# Out:
#            date  Price Per Gallon   datetime
# 6    2020-02-17             3.125 2020-02-17
# 7    2020-02-24             3.116 2020-02-24
# 8    2020-03-02             3.125 2020-03-02
# 9    2020-03-09             3.123 2020-03-09
# 10   2020-03-16             3.079 2020-03-16
# ..          ...               ...        ...
# 146  2022-10-24             5.049 2022-10-24
# 147  2022-10-31             4.934 2022-10-31
# 148  2022-11-07             4.879 2022-11-07
# 149  2022-11-14             4.901 2022-11-14
# 150  2022-11-21             4.822 2022-11-21
#
# [145 rows x 3 columns]

# %%
df = fuel_prices_weekly.merge(king_df_weekly, on="datetime")
df
# Out:
#            date  Price Per Gallon   datetime  \
# 0    2020-02-17             3.125 2020-02-17
# 1    2020-02-24             3.116 2020-02-24
# 2    2020-03-02             3.125 2020-03-02
# 3    2020-03-09             3.123 2020-03-09
# 4    2020-03-16             3.079 2020-03-16
# ..          ...               ...        ...
# 135  2022-09-19             4.653 2022-09-19
# 136  2022-09-26             4.867 2022-09-26
# 137  2022-10-03             5.365 2022-10-03
# 138  2022-10-10             5.504 2022-10-10
# 139  2022-10-17             5.287 2022-10-17
#
#      retail_and_recreation_percent_change_from_baseline  \
# 0                                             7.333333
# 1                                             2.428571
# 2                                             4.285714
# 3                                            -6.142857
# 4                                           -17.285714
# ..                                                 ...
# 135                                         -16.142857
# 136                                         -16.285714
# 137                                         -14.857143
# 138                                         -18.142857
# 139                                         -19.000000
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                             1.000000
# 1                                            -1.142857
# 2                                             3.714286
# 3                                             1.142857
# 4                                             4.714286
# ..                                                 ...
# 135                                          -9.285714
# 136                                          -9.285714
# 137                                          -9.428571
# 138                                         -10.428571
# 139                                         -10.800000
#
#      parks_percent_change_from_baseline  \
# 0                             31.333333
# 1                             38.142857
# 2                             30.857143
# 3                             24.142857
# 4                             22.142857
# ..                                  ...
# 135                           28.000000
# 136                           29.714286
# 137                           26.285714
# 138                           18.714286
# 139                           17.200000
#
#      transit_stations_percent_change_from_baseline  \
# 0                                        -0.666667
# 1                                         3.857143
# 2                                         3.285714
# 3                                       -15.000000
# 4                                       -33.000000
# ..                                             ...
# 135                                     -18.857143
# 136                                     -19.428571
# 137                                     -20.000000
# 138                                     -23.285714
# 139                                     -24.000000
#
#      workplaces_percent_change_from_baseline  \
# 0                                 -15.000000
# 1                                  -3.428571
# 2                                   1.000000
# 3                                 -12.428571
# 4                                 -28.000000
# ..                                       ...
# 135                               -35.285714
# 136                               -35.142857
# 137                               -34.000000
# 138                               -33.714286
# 139                               -36.400000
#
#      residential_percent_change_from_baseline
# 0                                    2.000000
# 1                                    0.000000
# 2                                   -0.285714
# 3                                    5.428571
# 4                                   10.857143
# ..                                        ...
# 135                                  6.142857
# 136                                  6.285714
# 137                                  6.285714
# 138                                  6.714286
# 139                                  7.400000
#
# [140 rows x 9 columns]

# %%
pearsonr(df["Price Per Gallon"], df["retail_and_recreation_percent_change_from_baseline"])
# Out:
# (0.6173367269730554, 4.543380578986182e-16)

# %%
combined = combined.iloc[:-5, :]
combined
# Out:
#           date  retail_and_recreation_percent_change_from_baseline  \
# 0   2020-02-15                                               -1.0
# 1   2020-02-16                                               13.0
# 2   2020-02-17                                               10.0
# 3   2020-02-18                                                4.0
# 4   2020-02-19                                                2.0
# ..         ...                                                ...
# 964 2022-10-06                                              -19.0
# 965 2022-10-07                                              -20.0
# 966 2022-10-08                                              -22.0
# 967 2022-10-09                                              -11.0
# 968 2022-10-10                                              -21.0
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                 -2.0
# 1                                                  1.0
# 2                                                  4.0
# 3                                                  2.0
# 4                                                  2.0
# ..                                                 ...
# 964                                               -8.0
# 965                                              -10.0
# 966                                              -14.0
# 967                                              -13.0
# 968                                              -11.0
#
#      parks_percent_change_from_baseline  \
# 0                                  11.0
# 1                                  19.0
# 2                                  64.0
# 3                                  51.0
# 4                                  62.0
# ..                                  ...
# 964                                17.0
# 965                                21.0
# 966                                41.0
# 967                                18.0
# 968                                 2.0
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              8.0
# 1                                              3.0
# 2                                            -13.0
# 3                                              6.0
# 4                                              6.0
# ..                                             ...
# 964                                          -29.0
# 965                                          -30.0
# 966                                           -6.0
# 967                                           -6.0
# 968                                          -31.0
#
#      workplaces_percent_change_from_baseline  \
# 0                                       -3.0
# 1                                       -2.0
# 2                                      -40.0
# 3                                       -8.0
# 4                                       -7.0
# ..                                       ...
# 964                                    -40.0
# 965                                    -43.0
# 966                                    -16.0
# 967                                    -10.0
# 968                                    -44.0
#
#      residential_percent_change_from_baseline        Day  Price Per Gallon
# 0                                         0.0   Saturday             3.125
# 1                                        -1.0     Sunday             3.125
# 2                                         7.0     Monday             3.125
# 3                                         1.0    Tuesday             3.116
# 4                                         0.0  Wednesday             3.116
# ..                                        ...        ...               ...
# 964                                       9.0   Thursday             5.504
# 965                                       9.0     Friday             5.504
# 966                                       0.0   Saturday             5.504
# 967                                       1.0     Sunday             5.504
# 968                                      10.0     Monday             5.504
#
# [969 rows x 9 columns]

# %%
# From Lab 1 (Alina Herri)
def bonferroni(p_values, alpha_total):
    """
    Returns decisions on p-values using the Bonferroni correction.
    
    Inputs:
        p_values: array of p-values
        alpha_total: desired family-wise error rate (FWER = P(at least one false discovery))
    
    Returns:
        decisions: binary array of same length as p-values, where `decisions[i]` is 1
        if `p_values[i]` is deemed significant, and 0 otherwise
    """
    decisions = np.array(list(map(lambda p: p <= (alpha_total/len(p_values)), p_values)))
    return decisions

# %%
# From Lab 1 Solutions
def benjamini_hochberg(p_values, alpha):
    """
    Returns decisions on p-values using Benjamini-Hochberg.
    
    Inputs:
        p_values: array of p-values
        alpha: desired FDR (FDR = E[# false positives / # positives])
    
    Returns:
        decisions: binary array of same length as p-values, where `decisions[i]` is 1
        if `p_values[i]` is deemed significant, and 0 otherwise
    """
    n = len(p_values)
    sorted_p = np.sort(p_values)
    all_k = [k for k in range(n) if sorted_p[k] <= (k + 1) * (alpha / n)]
    if len(all_k) == 0:
        max_k = 0
    else:    
        max_k = max(all_k)
    threshold = sorted_p[max_k]
    decisions = p_values <= threshold
    return decisions

# %%
columns = ["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "parks_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]
alpha = 0.05
for col in columns:
    print(col)
    p_values = []
    for i in range(1000):
        sample = resample(combined, replace=True, n_samples=100, random_state=i)
        p_value = pearsonr(sample["Price Per Gallon"], sample[col])[1]
        p_values.append(p_value)
    bonferroni_decisions = bonferroni(p_values, alpha)
    print("Bonferroni: " + str(len(bonferroni_decisions) - bonferroni_decisions.sum()))
    bh_decisions = benjamini_hochberg(p_values, alpha)
    print("BH: " + str(len(bh_decisions) - bh_decisions.sum()))
# Out:
# retail_and_recreation_percent_change_from_baseline
# Bonferroni: 3
# BH: 0
# grocery_and_pharmacy_percent_change_from_baseline
# Bonferroni: 860
# BH: 104
# parks_percent_change_from_baseline
# Bonferroni: 1000
# BH: 999
# transit_stations_percent_change_from_baseline
# Bonferroni: 1
# BH: 0
# workplaces_percent_change_from_baseline
# Bonferroni: 963
# BH: 488
# residential_percent_change_from_baseline
# Bonferroni: 39
# BH: 0

# %% [markdown]
# # Causal Inference

# %%
is_weekend = []
for i in range(len(combined)):
    day = combined.iloc[i]["Day"]
    if day == "Saturday" or day == "Sunday":
        is_weekend.append(1)
    else:
        is_weekend.append(0)
combined["Weekend"] = is_weekend

# %%
fuel_threshold = []
for i in range(len(combined)):
    fuel_price = combined.iloc[i]["Price Per Gallon"]
    if fuel_price > 4:
        fuel_threshold.append(1)
    else:
        fuel_threshold.append(0)
combined["Fuel Threshold"] = fuel_threshold

# %%
from sklearn.linear_model import LogisticRegression as LR
lr = LR(penalty='none', max_iter=200, random_state=0)
Z = np.array(combined["Weekend"])
Y = np.array(combined["workplaces_percent_change_from_baseline"])
X = np.array(combined[["Price Per Gallon"]])
lr.fit(X, Z)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='none',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
import numpy as np
def estimate_treatment_effect(lr, X, Y, Z):
    propensity_scores = lr.predict_proba(X)
    total = 0
    for i in range(len(X)):
        e_hat0 = propensity_scores[i, 0]
        e_hat1 = propensity_scores[i, 1]
        term1 = Z[i] * Y[i] / e_hat0
        term2 = (1 - Z[i]) * Y[i] / (e_hat1)
        total += (term1 - term2)
    tau = total / len(X)
    return tau

# %%
estimate_treatment_effect(lr, X, Y, Z)
# Out:
# 119.19506366798005

# %%
def estimate_naive_treatment_effect(Y, Z):
    total1, total0 = 0, 0
    n = len(Y)
    n1 = sum(Z)
    n0 = n - n1
    for i in range(n):
        total1 += Y[i] * Z[i]
        total0 += Y[i] * (1-Z[i])
    tau = (total1 / n1) - (total0 / n0)
    return tau

# %%
estimate_naive_treatment_effect(Y, Z)
# Out:
# 33.51226977896699

# %%
combined
# Out:
#           date  retail_and_recreation_percent_change_from_baseline  \
# 0   2020-02-15                                               -1.0
# 1   2020-02-16                                               13.0
# 2   2020-02-17                                               10.0
# 3   2020-02-18                                                4.0
# 4   2020-02-19                                                2.0
# ..         ...                                                ...
# 964 2022-10-06                                              -19.0
# 965 2022-10-07                                              -20.0
# 966 2022-10-08                                              -22.0
# 967 2022-10-09                                              -11.0
# 968 2022-10-10                                              -21.0
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                 -2.0
# 1                                                  1.0
# 2                                                  4.0
# 3                                                  2.0
# 4                                                  2.0
# ..                                                 ...
# 964                                               -8.0
# 965                                              -10.0
# 966                                              -14.0
# 967                                              -13.0
# 968                                              -11.0
#
#      parks_percent_change_from_baseline  \
# 0                                  11.0
# 1                                  19.0
# 2                                  64.0
# 3                                  51.0
# 4                                  62.0
# ..                                  ...
# 964                                17.0
# 965                                21.0
# 966                                41.0
# 967                                18.0
# 968                                 2.0
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              8.0
# 1                                              3.0
# 2                                            -13.0
# 3                                              6.0
# 4                                              6.0
# ..                                             ...
# 964                                          -29.0
# 965                                          -30.0
# 966                                           -6.0
# 967                                           -6.0
# 968                                          -31.0
#
#      workplaces_percent_change_from_baseline  \
# 0                                       -3.0
# 1                                       -2.0
# 2                                      -40.0
# 3                                       -8.0
# 4                                       -7.0
# ..                                       ...
# 964                                    -40.0
# 965                                    -43.0
# 966                                    -16.0
# 967                                    -10.0
# 968                                    -44.0
#
#      residential_percent_change_from_baseline        Day  Price Per Gallon  \
# 0                                         0.0   Saturday             3.125
# 1                                        -1.0     Sunday             3.125
# 2                                         7.0     Monday             3.125
# 3                                         1.0    Tuesday             3.116
# 4                                         0.0  Wednesday             3.116
# ..                                        ...        ...               ...
# 964                                       9.0   Thursday             5.504
# 965                                       9.0     Friday             5.504
# 966                                       0.0   Saturday             5.504
# 967                                       1.0     Sunday             5.504
# 968                                      10.0     Monday             5.504
#
#      Weekend  Fuel Threshold
# 0          1               0
# 1          1               0
# 2          0               0
# 3          0               0
# 4          0               0
# ..       ...             ...
# 964        0               1
# 965        0               1
# 966        1               1
# 967        1               1
# 968        0               1
#
# [969 rows x 11 columns]

# %%
lr2 = LR(penalty='none', max_iter=200, random_state=0)
Z2 = np.array(combined["Fuel Threshold"])
Y2 = np.array(combined["workplaces_percent_change_from_baseline"])
X2 = np.array(combined[["retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "parks_percent_change_from_baseline", "transit_stations_percent_change_from_baseline", "residential_percent_change_from_baseline", "Weekend"]])
lr2.fit(X2, Z2)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='none',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
estimate_treatment_effect(lr2, X2, Y2, Z2)
# Out:
# 276751.84797203605
